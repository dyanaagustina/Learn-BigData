# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

data = pd.read_csv('../input/19560-indian-takeaway-orders/restaurant-1-orders.csv')
data.head()
# Out:
#    Order Number        Order Date            Item Name  Quantity  \
# 0         16118  03/08/2019 20:25        Plain Papadum         2
# 1         16118  03/08/2019 20:25     King Prawn Balti         1
# 2         16118  03/08/2019 20:25          Garlic Naan         1
# 3         16118  03/08/2019 20:25        Mushroom Rice         1
# 4         16118  03/08/2019 20:25  Paneer Tikka Masala         1
#
#    Product Price  Total products
# 0           0.80               6
# 1          12.95               6
# 2           2.95               6
# 3           3.95               6
# 4           8.95               6

# %%
data.shape
# Out:
# (74818, 6)

# %%
data.isnull().count()
# Out:
# Order Number      74818
# Order Date        74818
# Item Name         74818
# Quantity          74818
# Product Price     74818
# Total products    74818
# dtype: int64

# %%
data_basket = (data.groupby(['Order Number', 'Item Name'])['Quantity']
              .sum().unstack().reset_index().fillna(0)
              .set_index('Order Number'))

# %%
data_basket.head()
# Out:
# Item Name     Aloo Chaat  Aloo Gobi  Aloo Methi  Baingan Hari Mirch  \
# Order Number
# 630                  0.0        0.0         0.0                 0.0
# 647                  0.0        0.0         0.0                 0.0
# 648                  0.0        0.0         0.0                 0.0
# 651                  0.0        0.0         0.0                 0.0
# 764                  0.0        0.0         0.0                 0.0
#
# Item Name     Bengal Fish Biryani  Bengal Fish Karahi  Bengal Fry Fish  \
# Order Number
# 630                           0.0                 0.0              0.0
# 647                           0.0                 0.0              0.0
# 648                           0.0                 0.0              0.0
# 651                           0.0                 0.0              0.0
# 764                           0.0                 0.0              0.0
#
# Item Name     Bengal King Prawn  Bengal Salad  Bhindi Bhajee  ...  \
# Order Number                                                  ...
# 630                         0.0           0.0            0.0  ...
# 647                         0.0           0.0            0.0  ...
# 648                         0.0           0.0            0.0  ...
# 651                         0.0           0.0            0.0  ...
# 764                         0.0           0.0            0.0  ...
#
# Item Name     Vegetable Rice  Vegetable Roll  Vegetable Samosa  Vindaloo  \
# Order Number
# 630                      0.0             0.0               0.0       0.0
# 647                      0.0             0.0               0.0       0.0
# 648                      0.0             0.0               0.0       0.0
# 651                      0.0             0.0               0.0       0.0
# 764                      0.0             0.0               0.0       0.0
#
# Item Name     Vindaloo - Chicken  Vindaloo - Chicken Tikka  \
# Order Number
# 630                          0.0                       0.0
# 647                          0.0                       0.0
# 648                          0.0                       0.0
# 651                          0.0                       0.0
# 764                          0.0                       0.0
#
# Item Name     Vindaloo - King Prawn  Vindaloo - Lamb  Vindaloo - Prawn  \
# Order Number
# 630                             0.0              0.0               0.0
# 647                             0.0              0.0               0.0
# 648                             0.0              0.0               0.0
# 651                             0.0              0.0               0.0
# 764                             0.0              0.0               0.0
#
# Item Name     Vindaloo Sauce
# Order Number
# 630                      0.0
# 647                      0.0
# 648                      0.0
# 651                      0.0
# 764                      0.0
#
# [5 rows x 248 columns]

# %%
data_basket.shape
# Out:
# (13397, 248)

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
data_basket.columns
# Out:
# Index(['Aloo Chaat', 'Aloo Gobi', 'Aloo Methi', 'Baingan Hari Mirch',
#        'Bengal Fish Biryani', 'Bengal Fish Karahi', 'Bengal Fry Fish',
#        'Bengal King Prawn', 'Bengal Salad', 'Bhindi Bhajee',
#        ...
#        'Vegetable Rice', 'Vegetable Roll', 'Vegetable Samosa', 'Vindaloo',
#        'Vindaloo - Chicken', 'Vindaloo - Chicken Tikka',
#        'Vindaloo - King Prawn', 'Vindaloo - Lamb', 'Vindaloo - Prawn',
#        'Vindaloo Sauce'],
#       dtype='object', name='Item Name', length=248)

# %%
data_basket_sets = data_basket.applymap(encode_units)

data_basket_sets
# Out:
# Item Name     Aloo Chaat  Aloo Gobi  Aloo Methi  Baingan Hari Mirch  \
# Order Number
# 630                    0          0           0                   0
# 647                    0          0           0                   0
# 648                    0          0           0                   0
# 651                    0          0           0                   0
# 764                    0          0           0                   0
# ...                  ...        ...         ...                 ...
# 16114                  0          0           0                   0
# 16115                  0          0           0                   0
# 16116                  1          0           0                   0
# 16117                  0          0           0                   0
# 16118                  0          0           0                   0
#
# Item Name     Bengal Fish Biryani  Bengal Fish Karahi  Bengal Fry Fish  \
# Order Number
# 630                             0                   0                0
# 647                             0                   0                0
# 648                             0                   0                0
# 651                             0                   0                0
# 764                             0                   0                0
# ...                           ...                 ...              ...
# 16114                           0                   0                0
# 16115                           0                   0                0
# 16116                           0                   0                0
# 16117                           0                   0                0
# 16118                           0                   0                0
#
# Item Name     Bengal King Prawn  Bengal Salad  Bhindi Bhajee  ...  \
# Order Number                                                  ...
# 630                           0             0              0  ...
# 647                           0             0              0  ...
# 648                           0             0              0  ...
# 651                           0             0              0  ...
# 764                           0             0              0  ...
# ...                         ...           ...            ...  ...
# 16114                         0             0              0  ...
# 16115                         0             0              0  ...
# 16116                         0             0              0  ...
# 16117                         0             0              0  ...
# 16118                         0             0              0  ...
#
# Item Name     Vegetable Rice  Vegetable Roll  Vegetable Samosa  Vindaloo  \
# Order Number
# 630                        0               0                 0         0
# 647                        0               0                 0         0
# 648                        0               0                 0         0
# 651                        0               0                 0         0
# 764                        0               0                 0         0
# ...                      ...             ...               ...       ...
# 16114                      0               0                 0         0
# 16115                      0               0                 0         0
# 16116                      0               0                 0         0
# 16117                      0               0                 0         0
# 16118                      0               0                 0         0
#
# Item Name     Vindaloo - Chicken  Vindaloo - Chicken Tikka  \
# Order Number
# 630                            0                         0
# 647                            0                         0
# 648                            0                         0
# 651                            0                         0
# 764                            0                         0
# ...                          ...                       ...
# 16114                          0                         0
# 16115                          0                         0
# 16116                          0                         0
# 16117                          0                         0
# 16118                          0                         0
#
# Item Name     Vindaloo - King Prawn  Vindaloo - Lamb  Vindaloo - Prawn  \
# Order Number
# 630                               0                0                 0
# 647                               0                0                 0
# 648                               0                0                 0
# 651                               0                0                 0
# 764                               0                0                 0
# ...                             ...              ...               ...
# 16114                             0                0                 0
# 16115                             0                0                 0
# 16116                             0                0                 0
# 16117                             0                1                 0
# 16118                             0                0                 0
#
# Item Name     Vindaloo Sauce
# Order Number
# 630                        0
# 647                        0
# 648                        0
# 651                        0
# 764                        0
# ...                      ...
# 16114                      0
# 16115                      0
# 16116                      0
# 16117                      0
# 16118                      0
#
# [13397 rows x 248 columns]

# %%
data_basket_sets.shape
# Out:
# (13397, 248)

# %%
freq_itemset = apriori(data_basket_sets, min_support=0.05, use_colnames=True)
freq_itemset.shape
# Out:
# (45, 2)

# %%
freq_itemset
# Out:
#      support                                    itemsets
# 0   0.130776                               (Bombay Aloo)
# 1   0.073151                            (Butter Chicken)
# 2   0.087333                                   (Chapati)
# 3   0.051653                             (Chicken Tikka)
# 4   0.060088                      (Chicken Tikka (Main))
# 5   0.159215                      (Chicken Tikka Masala)
# 6   0.196163                               (Garlic Naan)
# 7   0.101665                                (Keema Naan)
# 8   0.087482                                     (Korma)
# 9   0.070389                           (Korma - Chicken)
# 10  0.058819                                    (Madras)
# 11  0.154438                             (Mango Chutney)
# 12  0.088975                               (Meat Samosa)
# 13  0.109204                                (Mint Sauce)
# 14  0.108382                             (Mushroom Rice)
# 15  0.179219                              (Onion Bhajee)
# 16  0.077032                             (Onion Chutney)
# 17  0.114578                             (Peshwari Naan)
# 18  0.352392                                (Pilau Rice)
# 19  0.280063                                (Plain Naan)
# 20  0.268418                             (Plain Papadum)
# 21  0.176831                                (Plain Rice)
# 22  0.089124                                 (Saag Aloo)
# 23  0.065313                   (Pilau Rice, Bombay Aloo)
# 24  0.085094          (Chicken Tikka Masala, Pilau Rice)
# 25  0.064417          (Chicken Tikka Masala, Plain Naan)
# 26  0.059864       (Chicken Tikka Masala, Plain Papadum)
# 27  0.081436                   (Pilau Rice, Garlic Naan)
# 28  0.053146                (Plain Papadum, Garlic Naan)
# 29  0.053743                 (Mint Sauce, Mango Chutney)
# 30  0.073524                 (Pilau Rice, Mango Chutney)
# 31  0.052251                 (Plain Naan, Mango Chutney)
# 32  0.113010              (Plain Papadum, Mango Chutney)
# 33  0.080839                 (Plain Papadum, Mint Sauce)
# 34  0.079421                  (Pilau Rice, Onion Bhajee)
# 35  0.053296                  (Onion Bhajee, Plain Naan)
# 36  0.066433               (Onion Bhajee, Plain Papadum)
# 37  0.058297              (Plain Papadum, Onion Chutney)
# 38  0.053893                 (Peshwari Naan, Pilau Rice)
# 39  0.129133                    (Pilau Rice, Plain Naan)
# 40  0.133239                 (Pilau Rice, Plain Papadum)
# 41  0.084795                 (Plain Papadum, Plain Naan)
# 42  0.068150                    (Plain Rice, Plain Naan)
# 43  0.056505                 (Plain Papadum, Plain Rice)
# 44  0.058147  (Pilau Rice, Plain Papadum, Mango Chutney)

# %%
rules = association_rules(freq_itemset, metric="lift", min_threshold=1)
rules.head()
# Out:
#               antecedents             consequents  antecedent support  \
# 0            (Pilau Rice)           (Bombay Aloo)            0.352392
# 1           (Bombay Aloo)            (Pilau Rice)            0.130776
# 2  (Chicken Tikka Masala)            (Pilau Rice)            0.159215
# 3            (Pilau Rice)  (Chicken Tikka Masala)            0.352392
# 4  (Chicken Tikka Masala)            (Plain Naan)            0.159215
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.130776  0.065313    0.185342  1.417253  0.019229    1.066981
# 1            0.352392  0.065313    0.499429  1.417253  0.019229    1.293738
# 2            0.352392  0.085094    0.534459  1.516658  0.028988    1.391085
# 3            0.159215  0.085094    0.241474  1.516658  0.028988    1.108447
# 4            0.280063  0.064417    0.404594  1.444657  0.019827    1.209155

# %%
rules.sort_values(by=['confidence'], ascending=False)
rules.head(10)
# Out:
#               antecedents             consequents  antecedent support  \
# 0            (Pilau Rice)           (Bombay Aloo)            0.352392
# 1           (Bombay Aloo)            (Pilau Rice)            0.130776
# 2  (Chicken Tikka Masala)            (Pilau Rice)            0.159215
# 3            (Pilau Rice)  (Chicken Tikka Masala)            0.352392
# 4  (Chicken Tikka Masala)            (Plain Naan)            0.159215
# 5            (Plain Naan)  (Chicken Tikka Masala)            0.280063
# 6  (Chicken Tikka Masala)         (Plain Papadum)            0.159215
# 7         (Plain Papadum)  (Chicken Tikka Masala)            0.268418
# 8            (Pilau Rice)           (Garlic Naan)            0.352392
# 9           (Garlic Naan)            (Pilau Rice)            0.196163
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.130776  0.065313    0.185342  1.417253  0.019229    1.066981
# 1            0.352392  0.065313    0.499429  1.417253  0.019229    1.293738
# 2            0.352392  0.085094    0.534459  1.516658  0.028988    1.391085
# 3            0.159215  0.085094    0.241474  1.516658  0.028988    1.108447
# 4            0.280063  0.064417    0.404594  1.444657  0.019827    1.209155
# 5            0.159215  0.064417    0.230011  1.444657  0.019827    1.091944
# 6            0.268418  0.059864    0.375996  1.400785  0.017128    1.172400
# 7            0.159215  0.059864    0.223026  1.400785  0.017128    1.082127
# 8            0.196163  0.081436    0.231095  1.178075  0.012310    1.045431
# 9            0.352392  0.081436    0.415145  1.178075  0.012310    1.107295

# %%
rules.sort_values(by=['lift'], ascending=False)
rules.head(10)
# Out:
#               antecedents             consequents  antecedent support  \
# 0            (Pilau Rice)           (Bombay Aloo)            0.352392
# 1           (Bombay Aloo)            (Pilau Rice)            0.130776
# 2  (Chicken Tikka Masala)            (Pilau Rice)            0.159215
# 3            (Pilau Rice)  (Chicken Tikka Masala)            0.352392
# 4  (Chicken Tikka Masala)            (Plain Naan)            0.159215
# 5            (Plain Naan)  (Chicken Tikka Masala)            0.280063
# 6  (Chicken Tikka Masala)         (Plain Papadum)            0.159215
# 7         (Plain Papadum)  (Chicken Tikka Masala)            0.268418
# 8            (Pilau Rice)           (Garlic Naan)            0.352392
# 9           (Garlic Naan)            (Pilau Rice)            0.196163
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.130776  0.065313    0.185342  1.417253  0.019229    1.066981
# 1            0.352392  0.065313    0.499429  1.417253  0.019229    1.293738
# 2            0.352392  0.085094    0.534459  1.516658  0.028988    1.391085
# 3            0.159215  0.085094    0.241474  1.516658  0.028988    1.108447
# 4            0.280063  0.064417    0.404594  1.444657  0.019827    1.209155
# 5            0.159215  0.064417    0.230011  1.444657  0.019827    1.091944
# 6            0.268418  0.059864    0.375996  1.400785  0.017128    1.172400
# 7            0.159215  0.059864    0.223026  1.400785  0.017128    1.082127
# 8            0.196163  0.081436    0.231095  1.178075  0.012310    1.045431
# 9            0.352392  0.081436    0.415145  1.178075  0.012310    1.107295

# %%
rules.sort_values(by=['confidence', 'lift'], ascending=False)
rules.head()
# Out:
#               antecedents             consequents  antecedent support  \
# 0            (Pilau Rice)           (Bombay Aloo)            0.352392
# 1           (Bombay Aloo)            (Pilau Rice)            0.130776
# 2  (Chicken Tikka Masala)            (Pilau Rice)            0.159215
# 3            (Pilau Rice)  (Chicken Tikka Masala)            0.352392
# 4  (Chicken Tikka Masala)            (Plain Naan)            0.159215
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.130776  0.065313    0.185342  1.417253  0.019229    1.066981
# 1            0.352392  0.065313    0.499429  1.417253  0.019229    1.293738
# 2            0.352392  0.085094    0.534459  1.516658  0.028988    1.391085
# 3            0.159215  0.085094    0.241474  1.516658  0.028988    1.108447
# 4            0.280063  0.064417    0.404594  1.444657  0.019827    1.209155
